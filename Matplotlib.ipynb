# %% [markdown]
# ## Installig Libraries

# %%
# !pip install matplotlib

# %% [markdown]
# ## Introduction to Matplotlib

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Why we use '%matplotlib inline' ? => You can use the magic function %matplotlib inline to enable the inline plotting, 
# where the plots/graphs will be displayed just below the cell where your plotting commands are written. 

# NOTE – If you are not in the interactive mode and using matplotlib for plotting graphs, 
# then the graph will only appear if you call the matplotlib.pyplot.show() function in previous versions of jupyter notebook.

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot([1, 2, 3, 4])

# %%
x = [1, 2, 3, 4]
y = [10, 12, 14, 16]
plt.plot(x, y);

# %%
# 1st method
fig = plt.figure() # creates a figure
ax = fig.add_subplot() # adds some axes
plt.show()

# %%
# 2nd method
fig = plt.figure() # creates a figure
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x, y) # adds some data
plt.show()

# %%
# 3rd method (recommended)
fig, ax = plt.subplots()
ax.plot(x, [100 , 200, 450, 550]);

# %%
# Matplotlib workflow

# 1) Import matplotlib and get it ready for plotting
# %matplotlib inline
import matplotlib.pyplot as plt

# 2) Prepare data
a = [1, 2, 3, 4, 5]
b = [100, 150, 350, 450, 800]

# 3) Setup plot
fig, ax = plt.subplots(figsize=(10 ,10)) # width, height

# 4) Plot data
plt.plot(a, b)

# 5) Customize plot
ax.set(title='Example Plot',
       xlabel='x-axis',
       ylabel='y-axis')

# 6) Save & show plot
fig.savefig("example_plot.png")

# %% [markdown]
# ## Making Figures With Numpy Array
#
# Note => Let's also talk about plot types.
#
# * Line Plot
# * Scatter Plot
# * Bar Plot
# * Histogram
# * Subplots

# %%
import numpy as np

# %%
# Create some data
numpy_array = np.linspace(0, 10, 50)
numpy_array
# Out:
# array([ 0.        ,  0.20408163,  0.40816327,  0.6122449 ,  0.81632653,
#         1.02040816,  1.2244898 ,  1.42857143,  1.63265306,  1.83673469,
#         2.04081633,  2.24489796,  2.44897959,  2.65306122,  2.85714286,
#         3.06122449,  3.26530612,  3.46938776,  3.67346939,  3.87755102,
#         4.08163265,  4.28571429,  4.48979592,  4.69387755,  4.89795918,
#         5.10204082,  5.30612245,  5.51020408,  5.71428571,  5.91836735,
#         6.12244898,  6.32653061,  6.53061224,  6.73469388,  6.93877551,
#         7.14285714,  7.34693878,  7.55102041,  7.75510204,  7.95918367,
#         8.16326531,  8.36734694,  8.57142857,  8.7755102 ,  8.97959184,
#         9.18367347,  9.3877551 ,  9.59183673,  9.79591837, 10.        ])

# %%
# Plot the data and create a line plot
fig, ax = plt.subplots()
ax.plot(numpy_array, numpy_array**2);

# %%
# Create scatter plot with the same data
fig, ax = plt.subplots()
ax.scatter(numpy_array, np.exp(numpy_array))
ax.plot();

# %%
# Make a scatter plot from dictionary
car_prices = {"Toyota" : 8000,
              "BMW" : 15000,
              "Opel" : 5000,
              "Mercedes" : 20000}
fig, ax = plt.subplots()
ax.scatter(car_prices.keys(), car_prices.values()) # x, y
ax.set(title="Car Sales Prices")
ax.plot();

# %%
# Make a bar plot

print("Without list : ", car_prices.keys())
print("With list : ", list(car_prices.keys()))

# dictionary.keys() and dictionary.values() returns a generator, which matplotlib cannot use directly.

fig, ax = plt.subplots()
ax.bar(list(car_prices.keys()), list(car_prices.values())) # x, y
ax.set(title="Car Sales Prices",
       ylabel="Prices ($)",
       xlabel="Models")
ax.plot();
# Out:
# Without list :  dict_keys(['Toyota', 'BMW', 'Opel', 'Mercedes'])
# With list :  ['Toyota', 'BMW', 'Opel', 'Mercedes']

# %%
# Make a horizontal bar plot

fig, ax = plt.subplots()
ax.barh(list(car_prices.keys()), list(car_prices.values())) # x, y
ax.set(title="Car Sales Prices",
       xlabel="Prices ($)",
       ylabel="Models")
ax.plot();

# %%
# Make a histogram

random_array = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(random_array, 15) # Second parameter shows number of bins
ax.plot();

# %% [markdown]
# ## Options For Subplots

# %%
# Subplot Option 1
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                             ncols=2,
                                             figsize=(10, 5))
# Plot to each different axis
ax1.plot(np.array([1, 2, 3]), np.array([1, 2, 3])/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(car_prices.keys(), car_prices.values());
ax4.hist(np.random.randn(1000));

# %%
# Subplot Option 2
fig, ax = plt.subplots(nrows=2,
                       ncols=2,
                       figsize=(10, 5))
# Plot to each different axis
ax[0, 0].plot(np.array([1, 2, 3]), np.array([1, 2, 3])/2);
ax[0, 1].scatter(np.random.random(10), np.random.random(10));
ax[1, 0].bar(car_prices.keys(), car_prices.values());
ax[1, 1].hist(np.random.randn(1000));

# %% [markdown]
# ## Plotting From Pandas Dataframes

# %% [markdown]
# #### Car Sales CSV File

# %%
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.Price = car_sales.Price.str.replace("[\$\,\.]", "")
car_sales
# Out:
# C:\Users\PC_2265\AppData\Local\Temp/ipykernel_11712/3473813206.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales.Price = car_sales.Price.str.replace("[\$\,\.]", "")
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
# Remove last two zeros
car_sales.Price = car_sales.Price.str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Date"] = pd.date_range("1/1/2020", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price       Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
# cumsum() : [4000, 5000, 7000] => [4000, 4000+5000, 4000+5000+7000] (cumulative)
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum() # type(car_sales["Price"][0]) = str , we need to assign int
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price       Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
# Plotting sales
car_sales.plot(x="Date", y="Total Sales");

# Plotting scatter
car_sales["Price"] = car_sales["Price"].astype(int) # reassigning price column to int
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
# How about a bar graph
x = np.random.rand(10, 4)

df = pd.DataFrame(x, columns=["a", "b", "c", "d"])
df
# Out:
#           a         b         c         d
# 0  0.627326  0.112988  0.438559  0.524108
# 1  0.250785  0.396191  0.891416  0.714150
# 2  0.182917  0.139271  0.457648  0.612105
# 3  0.602317  0.337316  0.121860  0.754368
# 4  0.311467  0.219875  0.999108  0.525701
# 5  0.119104  0.799635  0.609505  0.919315
# 6  0.430359  0.452925  0.194239  0.387259
# 7  0.204386  0.528847  0.709818  0.892475
# 8  0.539158  0.119462  0.080134  0.108299
# 9  0.894492  0.762890  0.258766  0.970452

# %%
df.plot.bar(figsize=(15, 7));
# df.plot(kind="bar", figsize=(15, 7));

# %%
car_sales.plot(x="Make", y="Odometer (KM)", kind="bar", figsize=(14, 7));

# %%
# How about a histograms
# car_sales["Odometer (KM)"].plot.hist(bins=15);
car_sales["Odometer (KM)"].plot(kind="hist", bins=15);

# %% [markdown]
# #### Heart Disease CSV File

# %%
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# Create a histogram of age
# heart_disease["age"].plot.hist(bins=10);
heart_disease.age.plot(kind="hist", bins=10);

# %%
# Frequencies of all columns
heart_disease.plot.hist(figsize=(15, 15), subplots=True);

# %% [markdown]
# #### Which one should you use? (pyplot vs matplotlib OO method)
# * When plotting something quickly, okay to use the pyplot method
# * When plotting something more advanced, use the Object-Oriented method

# %%
over_50 = heart_disease[heart_disease.age > 50]
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
# Pyplot method
# You may externally map values to color and supply a list/array of those colors to the scatter's c argument.
over_50.plot(kind="scatter",
                     x="age",
                     y="chol",
                     c="target",
                     figsize=(10, 5));

# %%
# OO method
fig, ax = plt.subplots(figsize=(10, 5))
over_50.plot(kind="scatter",
             x="age", 
             y="chol",
             c="target",
             ax=ax);

ax.set_xlim([45, 100]); # Set the x-axis view limits (age)

# %%
# OO method from scratch
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data
scatter = ax.scatter(x=over_50.age,
                     y=over_50.chol,
                     c=over_50.target)

# Customize the plot
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol")

# Add a legend
ax.legend(*scatter.legend_elements(), title="Target") # Create one scatter plot per item to appear in the legend and set the label accordingly

# Add a horizontal line 
ax.axhline(over_50.chol.mean(),
           linestyle="--");

# %%
############## Heart Disease Analysis From Scratch ##############

# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# Read and manipulate data
heart_disease = pd.read_csv("heart-disease.csv")
over_50 = heart_disease[heart_disease.age>50]

# Create figure two axes
fig, (ax0, ax1) = plt.subplots(nrows=2,
                               ncols=1,
                               sharex=True, # When subplots have a shared x-axis along a column, only the x tick labels of the bottom subplot are created.
                               figsize=(10, 10))

# Add data, title, meanline and legend to axes 0
ax0.scatter(over_50.age,
            over_50.chol,
            c=over_50.target,
            cmap="winter") # cmap : colormap

ax0.set(title="Hearth Disease and Cholesterol Levels",
        ylabel="Cholesterol", 
        xlim=[50, 80])

ax0.axhline(y=over_50.chol.mean(),
            color="r",
            linestyle="--")

ax0.legend(*scatter.legend_elements(), title="Target");

# Add data, title, meanline and legend to axes 1
ax1.scatter(over_50.age,
            over_50.thalach,
            c=over_50.target,
            cmap="winter") # this changes the colour scheme

ax1.set(title="Hearth Disease and Max Hearth Rate Levels",
        xlabel="Age",
        ylabel="Max Hearth Rate",
        ylim=[60, 200])

ax1.axhline(y=over_50.thalach.mean(),
            color="r",
            linestyle="--")

ax1.legend(*scatter.legend_elements(), title="Target")

# Title the figure
fig.suptitle("Hearth Disease Analysis", fontsize=15, fontweight="bold");

# %% [markdown]
# ## Customizing Matplotlib Plots and Getting Stylish

# %%
# See the different available styles
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales.Price.plot();

# %%
plt.style.use('seaborn-whitegrid')

# %%
car_sales.Price.plot();

# %%
plt.style.use('seaborn')

# %%
car_sales.Price.plot();

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
plt.style.use('ggplot')

# %%
car_sales.Price.plot();

# %%
# Create some data
x = np.random.randn(10, 4)
x
# Out:
# array([[ 0.71038441,  0.91254334, -0.13579284, -1.53470244],
#        [ 0.63789469, -1.76849172,  0.06702172, -0.51128872],
#        [-1.09765004,  0.27876872,  0.50212124, -1.00986797],
#        [ 0.80148593,  2.39724776,  0.40983887, -0.87236119],
#        [ 1.15447387, -0.58964209, -0.44908527,  0.02075331],
#        [ 0.59820194, -0.91711566, -0.09993078,  0.01390889],
#        [ 0.2257987 ,  1.74566258, -0.47897222,  0.32015963],
#        [-0.13011716, -0.17305009,  1.4243243 ,  1.78992204],
#        [-1.95600296,  0.51793196,  0.25510155, -1.075222  ],
#        [-0.0616178 ,  0.99082265,  0.0042634 ,  1.57105996]])

# %%
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.710384  0.912543 -0.135793 -1.534702
# 1  0.637895 -1.768492  0.067022 -0.511289
# 2 -1.097650  0.278769  0.502121 -1.009868
# 3  0.801486  2.397248  0.409839 -0.872361
# 4  1.154474 -0.589642 -0.449085  0.020753
# 5  0.598202 -0.917116 -0.099931  0.013909
# 6  0.225799  1.745663 -0.478972  0.320160
# 7 -0.130117 -0.173050  1.424324  1.789922
# 8 -1.956003  0.517932  0.255102 -1.075222
# 9 -0.061618  0.990823  0.004263  1.571060

# %%
# Customize our plot with the set() method
ax = df.plot(kind='bar')
# Add some labels and a title
ax.set(title="Random Number Bar Graph from DataFrame",
      xlabel="Row number",
      ylabel="Random number")
# Make the legends visible
ax.legend().set_visible(True)

# %% [markdown]
# ## Savig Plot

# %%
fig.savefig("saved_fig.png")
